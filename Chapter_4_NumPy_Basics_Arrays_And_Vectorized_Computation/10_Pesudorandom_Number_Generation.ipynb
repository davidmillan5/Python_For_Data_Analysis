# %%
import numpy as np

# %%
samples = np.random.standard_normal(size=(4,4))

# %%
samples
# Out:
# array([[ 0.83938688, -1.37895327, -0.67335758,  1.19947678],
#        [ 1.05654349,  0.01314108, -0.76074937, -0.65523666],
#        [-0.90056698,  0.0210348 , -0.38609738,  0.54000539],
#        [ 0.71561112, -1.35274145,  1.36437322,  0.86888468]])

# %%
from random import normalvariate

# %%
N = 1_000_000

# %%
# %timeit samples = [normalvariate(0,1) for _ in range(N)]
# Out:
# 815 ms ± 10.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit np.random.standard_normal(N)
# Out:
# 33.3 ms ± 1.68 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
rng = np.random.default_rng(seed=12345)

# %%
data = rng.standard_normal((2,3))

# %%
type(rng)
# Out:
# numpy.random._generator.Generator
