# %%
# %pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\usuario\appdata\local\programs\python\python313\lib\site-packages (2.3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
my_arr = np.arange(1_000_000)

# %%
my_list = list(range(1_000_000))

# %%
# %timeit my_arr2 = my_arr * 2
# Out:
# 5.67 ms ± 538 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit my_list2 = [ x * 2 for x in my_list]
# Out:
# 117 ms ± 8.86 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
